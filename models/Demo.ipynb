# %%
import os

try:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir("drive/My Drive/AML/Git_lastClone/neural-network")
    COLAB_IN = True
except:
    COLAB_IN = False
    

if COLAB_IN:
    # !ls
    # !pip install youtube_dl
    # !sudo apt-get install ffmpeg
    # !sudo apt-get install python3-magic
    # !pip install python-magic
    # !pip install pyAudioAnalysis scipy sklearn hmmlearn simplejson eyed3 pydub
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# dataset        metadata_model		 trailer_predictions.csv
# debug_set.csv  metadata_predictions.csv
# Demo.ipynb     trailer_model
# ...
#      |████████████████████████████████| 1.8MB 3.3MB/s
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# ...

# %%
# Run metadata-based predictions
os.chdir("metadata_model")
# !python predict.py ../debug_set.csv
os.chdir('..')

# %%
# Run trailer-based predictions
os.chdir("trailer_model")
# !python predict.py ../debug_set.csv
os.chdir('..')
